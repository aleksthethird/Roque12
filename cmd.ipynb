# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')

# %%
data = np.loadtxt('ukidss_plei_lodieu.txt')
z = data[:,8]
j = data[:,10]
prob = data[:,13]

# %%
z_j = z - j
r12_j = 15.930
r12_z = 17.655
r12_z_j = r12_z - r12_j

# %%
data = np.loadtxt('baraffe15_plei_iso.txt')
mass = data[:,0]
zmod = data[:,7]
jmod = data[:,8]
z_j_mod = zmod - jmod
Zmod = zmod + 5.6355 # assuming d=134pc
Jmod = jmod + 5.6355 # assuming d=134pc
m005 = 10.59 + 5.6355
m01 = 9.37 + 5.6355 
m02 = 8.31 + 5.6355 
m05 = 6.55 + 5.6355 
print(m05)
# Out:
# 12.185500000000001

# %%
plt.rc('font', family='serif')
plt.rc('xtick', labelsize='15')
plt.rc('ytick', labelsize='15')
fig = plt.figure(figsize=(10, 8))
plt.xlim(0,3)
plt.ylim(16.5,11.5)
plt.xlabel('Z-J',fontsize=20)
plt.ylabel('J',fontsize=20)
plt.plot(z_j,j,'b.')
plt.plot(r12_z_j,r12_j,'ro',markersize=15)
plt.plot(z_j_mod,Jmod,'g')
plt.text(0.1,m005,'0.05 Msun',fontsize=15)
plt.text(0.1,m01,'0.1 Msun',fontsize=15)
plt.text(0.1,m02,'0.2 Msun',fontsize=15)
plt.text(0.1,m05,'0.5 Msun',fontsize=15)
plt.text(r12_z_j+0.1,r12_j,'Roque 12', fontsize=15,color="red")
# Out:
# Text(1.8250000000000015, 15.93, 'Roque 12')
